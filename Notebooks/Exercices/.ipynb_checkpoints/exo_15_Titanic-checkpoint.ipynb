# %%
#importations
import pandas as pd    

#initialisation des variables
fichier_passagers = "./Data/Titanic/passengers.csv"
fichier_survie = "./Data/Titanic/survival.csv"

# %%
#récupération des dataframes
df_passagers = pd.read_csv(fichier_passagers, encoding='latin1', dtype={'PassengerId': 'int', 'Pclass': 'int', 'Name': 'string', 'Sex': 'string', 'Age': 'Float64', 'Fare': 'Float64'})
df_survie = pd.read_csv(fichier_survie, encoding='latin1', dtype={'PassengerId': 'int', 'Survived': 'boolean'})

display(df_passagers)
display(df_survie)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age     Fare
# 0       male  22.0     7.25
# 1     female  38.0  71.2833
# 2     female  26.0    7.925
# 3     female  35.0     53.1
# 4       male  35.0     8.05
# ...      ...   ...      ...
# 1304    male  <NA>     8.05
# 1305  female  39.0    108.9
# 1306    male  38.5     7.25
# 1307    male  <NA>     8.05
# 1308    male  <NA>  22.3583
#
# [1309 rows x 6 columns]
#       PassengerId  Survived
# 0               1     False
# 1               2      True
# 2               3      True
# 3               4      True
# 4               5     False
# ...           ...       ...
# 1304         1305     False
# 1305         1306      True
# 1306         1307     False
# 1307         1308     False
# 1308         1309     False
#
# [1309 rows x 2 columns]

# %%
df_titanic = df_passagers.join(df_survie, lsuffix='PassengerId', rsuffix='PassengerId')
df_titanic
# Out:
#       PassengerIdPassengerId  Pclass  \
# 0                          1       3
# 1                          2       1
# 2                          3       3
# 3                          4       1
# 4                          5       3
# ...                      ...     ...
# 1304                    1305       3
# 1305                    1306       1
# 1306                    1307       3
# 1307                    1308       3
# 1308                    1309       3
#
#                                                    Name     Sex   Age  \
# 0                               Braund, Mr. Owen Harris    male  22.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                Heikkinen, Miss. Laina  female  26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                              Allen, Mr. William Henry    male  35.0
# ...                                                 ...     ...   ...
# 1304                                 Spector, Mr. Woolf    male  <NA>
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5
# 1307                                Ware, Mr. Frederick    male  <NA>
# 1308                           Peter, Master. Michael J    male  <NA>
#
#          Fare  PassengerIdPassengerId  Survived
# 0        7.25                       1     False
# 1     71.2833                       2      True
# 2       7.925                       3      True
# 3        53.1                       4      True
# 4        8.05                       5     False
# ...       ...                     ...       ...
# 1304     8.05                    1305     False
# 1305    108.9                    1306      True
# 1306     7.25                    1307     False
# 1307     8.05                    1308     False
# 1308  22.3583                    1309     False
#
# [1309 rows x 8 columns]

# %%
# Combien y a t-il de passagers dans notre base de données ?
nb_passagers = len(df_titanic)
nb_passagers
# Out:
# 1309

# %%
# Quelle est la moyenne du prix du trajet ?
moyenne_prix_trajet = df_titanic['Fare'].mean()
moyenne_prix_trajet
# Out:
# 33.29547928134557

# %%
# Quels passagers ont payé les billets les plus chers ?
max_prix_trajet = df_titanic['Fare'].max()
df_passagers_ticket_le_plus_cher = df_titanic[df_titanic['Fare'] == max_prix_trajet]
df_passagers_ticket_le_plus_cher
# Out:
#       PassengerIdPassengerId  Pclass  \
# 258                      259       1
# 679                      680       1
# 737                      738       1
# 1234                    1235       1
#
#                                                    Name     Sex   Age  \
# 258                                    Ward, Miss. Anna  female  35.0
# 679                  Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 737                              Lesurer, Mr. Gustave J    male  35.0
# 1234  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0
#
#           Fare  PassengerIdPassengerId  Survived
# 258   512.3292                     259      True
# 679   512.3292                     680      True
# 737   512.3292                     738      True
# 1234  512.3292                    1235      True

# %%
# Quelles personnes n’ont pas payé leurs billets de 1ère classe ?
df_passagers_billet_premiere_classe_gratuit = df_titanic[(df_titanic['Pclass'] == 1) & (df_titanic['Fare'] == 0)]
df_passagers_billet_premiere_classe_gratuit
# Out:
#       PassengerIdPassengerId  Pclass                                   Name  \
# 263                      264       1                  Harrison, Mr. William
# 633                      634       1          Parr, Mr. William Henry Marsh
# 806                      807       1                 Andrews, Mr. Thomas Jr
# 815                      816       1                       Fry, Mr. Richard
# 822                      823       1        Reuchlin, Jonkheer. John George
# 1157                    1158       1  Chisholm, Mr. Roderick Robert Crispin
# 1263                    1264       1                Ismay, Mr. Joseph Bruce
#
#        Sex   Age  Fare  PassengerIdPassengerId  Survived
# 263   male  40.0   0.0                     264     False
# 633   male  <NA>   0.0                     634     False
# 806   male  39.0   0.0                     807     False
# 815   male  <NA>   0.0                     816     False
# 822   male  38.0   0.0                     823     False
# 1157  male  <NA>   0.0                    1158     False
# 1263  male  49.0   0.0                    1264     False

# %%
# Quelle personne a obtenu le billet de première classe le moins cher ?
df_titanic_classe1 = df_titanic[df_titanic['Pclass'] == 1]
billet_classe_1_le_moins_cher = df_titanic_classe1[df_titanic_classe1['Fare'] > 0]['Fare'].min()
df_titanic_classe1[df_titanic_classe1['Fare'] == billet_classe_1_le_moins_cher]
# Out:
#      PassengerIdPassengerId  Pclass                      Name   Sex   Age  \
# 872                     873       1  Carlsson, Mr. Frans Olof  male  33.0
#
#      Fare  PassengerIdPassengerId  Survived
# 872   5.0                     873     False

# %%
# Quelle est la personne la plus jeune ? et la personne la plus âgée à bord du Titanic ?
min_age = df_titanic['Age'].min()
max_age = df_titanic['Age'].max()
df_passagers_les_plus_jeunes = df_titanic[df_titanic['Age'] == min_age]
df_passagers_les_plus_vieux = df_titanic[df_titanic['Age'] == max_age]

print(f"La personne la plus jeune est: {df_passagers_les_plus_jeunes['Name'].iloc[0]}")
display(df_passagers_les_plus_jeunes)
print(f"La personne la plus vieille est: {df_passagers_les_plus_vieux['Name'].iloc[0]}")
display(df_passagers_les_plus_vieux)
# Out:
# La personne la plus jeune est: Dean, Miss. Elizabeth Gladys Millvina""
#       PassengerIdPassengerId  Pclass                                     Name  \
# 1245                    1246       3  Dean, Miss. Elizabeth Gladys Millvina""
#
#          Sex   Age    Fare  PassengerIdPassengerId  Survived
# 1245  female  0.17  20.575                    1246      True
# La personne la plus vieille est: Barkworth, Mr. Algernon Henry Wilson
#      PassengerIdPassengerId  Pclass                                  Name  \
# 630                     631       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  Fare  PassengerIdPassengerId  Survived
# 630  male  80.0  30.0                     631      True

# %%
# Quel est le prix médian des billets de 1ère, 2ème ou 3ème classe ?
df_prix_median_par_classe = df_titanic.groupby(by='Pclass')['Fare'].median().reset_index()
display(df_prix_median_par_classe)
# Out:
#    Pclass     Fare
# 0       1     60.0
# 1       2  15.0458
# 2       3     8.05

# %%
# Affichage du prix median par classe
df_prix_median_par_classe.plot(kind='bar', x='Pclass', y='Fare', color='skyblue', title='Price per class', grid=True)
# Out:
# <Axes: title={'center': 'Price per class'}, xlabel='Pclass'>
