# %%
import pandas as pd

# %%
df_clients = pd.DataFrame({
    'client_id': [1, 2, 3, 4],
    'nom': ['Alice', 'Bob', 'Charlie', 'David'],
    'ville': ['Paris', 'Lyon', 'Marseille', 'Toulouse']
})

# %%
df_clients
# Out:
#    client_id      nom      ville
# 0          1    Alice      Paris
# 1          2      Bob       Lyon
# 2          3  Charlie  Marseille
# 3          4    David   Toulouse

# %%
noms_colonnes = list(df_clients.columns)
noms_colonnes.remove("nom")
noms_colonnes
# Out:
# ['client_id', 'ville']

# %%
df_sortie = df_clients[noms_colonnes]
df_sortie
# Out:
#    client_id      ville
# 0          1      Paris
# 1          2       Lyon
# 2          3  Marseille
# 3          4   Toulouse
